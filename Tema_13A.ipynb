# %% [markdown]
# <a href="https://colab.research.google.com/github/alberzenon/AprendizajeAutomatico/blob/main/Tema_13A.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from sklearn import datasets
from sklearn.svm import LinearSVC
from sklearn.preprocessing import StandardScaler

# %%
data_iris = datasets.load_iris()

# %%
caracteristicas = data_iris.data[:100, :2]
caracteristicas.shape
# Out:
# (100, 2)

# %%
etiquetas = data_iris.target[:100]
etiquetas.shape
# Out:
# (100,)

# %%
plt.scatter(caracteristicas[:,0], caracteristicas[:,1], c=etiquetas)
plt.show()

# %%
scaler = StandardScaler()
caracteristicas_normalizadas = scaler.fit_transform(caracteristicas)

# %%
plt.scatter(caracteristicas_normalizadas[:,0], caracteristicas_normalizadas[:,1], c=etiquetas)
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(caracteristicas_normalizadas, etiquetas, test_size=0.2)

# %%
plt.scatter(X_train[:,0], X_train[:,1], c=y_train)
plt.show()

# %%
SVC = LinearSVC(C=1)
modelo_entrenado = SVC.fit(X_train,y_train)

# %%
valores_pred = SVC.predict(X_test)

# %%
from sklearn import metrics
metrics.accuracy_score(y_test,valores_pred)
# Out:
# 1.0

# %%
metrics.confusion_matrix(y_test,valores_pred)
# Out:
# array([[ 9,  0],
#        [ 0, 11]])
